# %% [markdown]
# # 25 — CatBoost deferred identities
#
# **Decision:** promote the fixed 44% accepted XGBoost / 36% accepted Random Forest / 20% complete-identity CatBoost vote to local-test confirmation. It reaches 81.740%, a 0.116-point gain with four fold wins.

# %%
from pathlib import Path
import json
import pandas as pd
PROJECT_DIR = Path('../..').resolve()
OUTPUT_DIR = PROJECT_DIR / '.runtime' / 'catboost-identity-screen'
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col='candidate')
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
result

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — test ordered native categoricals over deferred identities.
# 2. **Gather the data** — reuse six audited source identities.
# 3. **Explore the data** — use prior support and target-encoding evidence.
# 4. **Clean and preprocess the data** — normalise case and whitespace conservatively.
# 5. **Select and engineer features** — add six native categories to the accepted frame.
# 6. **Define the machine-learning task** — unchanged three-class classification.
# 7. **Partition the data** — preserve outer folds and inner early stopping.
# 8. **Select and train candidate methods** — one depth-8 CatBoost specification.
# 9. **Evaluate and interpret the results** — compare four fixed low-weight additions.
# 10. **Deploy and iterate** — freeze the gate-passing recipe for one local-test confirmation.

# %% [markdown]
# ## Results

# %%
summary.style.format({
    'mean_accuracy': '{:.3%}', 'accuracy_change': '{:+.3%}',
    'worst_fold_change': '{:+.3%}', 'repair_recall_change': '{:+.3%}',
})

# %% [markdown]
# ## Interpretation
#
# Complete identities improve CatBoost standalone by 0.339 points, but the model remains weaker than the accepted components. Its useful contribution is error diversity. Preserving the accepted 55:45 ratio in 80% of the vote produces fixed weights of 44%, 36% and 20%.

# %% [markdown]
# ## Frozen next checkpoint
#
# Refit both the selected three-component recipe and the accepted two-component recipe on the complete development partition, then score the already-reserved local test once. Do not alter weights or fields in response. Because earlier workflows have already used this local test, treat it as confirmation rather than a pristine final estimate.
