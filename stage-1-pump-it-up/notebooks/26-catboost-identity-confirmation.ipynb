# %% [markdown]
# # 26 — CatBoost identity confirmation
#
# **Decision:** promote the frozen 44:36:20 recipe to a full-data refit. It reaches 81.086% on the 11,880-row local test, a +0.387-point gain and 46 net additional correct classifications.

# %%
from pathlib import Path
import json
import pandas as pd
PROJECT_DIR = Path('../..').resolve()
OUTPUT_DIR = PROJECT_DIR / '.runtime' / 'catboost-identity-confirmation'
metrics = pd.read_csv(OUTPUT_DIR / 'local-test-metrics.csv', index_col=0)
paired = pd.read_csv(OUTPUT_DIR / 'paired-summary.csv', index_col=0).iloc[:, 0]
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
result

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — confirm transfer of the preselected recipe.
# 2. **Gather the data** — reuse the frozen development and local-test partitions.
# 3. **Explore the data** — use only recorded development-fold evidence before fitting.
# 4. **Clean and preprocess the data** — retain the accepted preprocessing and identity normalisation.
# 5. **Select and engineer features** — keep the already-frozen 29-plus-six representation.
# 6. **Define the machine-learning task** — unchanged three-class classification.
# 7. **Partition the data** — fit 47,520 development rows and score 11,880 held-out rows once.
# 8. **Select and train candidate methods** — reuse frozen weights, settings and median tree counts.
# 9. **Evaluate and interpret the results** — compare paired accuracy, recalls and probability quality.
# 10. **Deploy and iterate** — refit all labelled rows and generate, but do not yet upload, a competition candidate.

# %% [markdown]
# ## Local-test results

# %%
metrics

# %%
paired

# %% [markdown]
# ## Interpretation
#
# The candidate changes 209 hard predictions. It gets 118 rows right that only the accepted recipe misses and loses 72 rows that only the accepted recipe gets right. The exact paired p-value is 0.00104 and the deterministic paired-bootstrap 95% interval is +0.160 to +0.623 accuracy points. Functional recall improves 0.806 points, repair recall falls 0.695 points and non-functional recall is unchanged.

# %% [markdown]
# ## Full-data candidate
#
# The unchanged full-data recipe produced a validated 14,850-row competition file with SHA-256 `76cf24053f136d89262b23b626c932e2f5b609ca197e16d2cb7e4b46897bb006`. It differs from the accepted submission on 1.576% of rows. Prediction shares were recorded without retuning, and the file remains unuploaded while the recorded daily allowance is 3/3.
