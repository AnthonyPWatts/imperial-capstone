# %% [markdown]
# # 27 — CatBoost identity context
#
# **Decision:** retain the complete-identity candidate. The fixed context representation ties its 81.7403% vote, wins only two folds and loses another 0.463 points of repair recall.

# %%
from pathlib import Path
import json
import pandas as pd
PROJECT_DIR = Path('../..').resolve()
OUTPUT_DIR = PROJECT_DIR / '.runtime' / 'catboost-identity-context-screen'
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col='candidate')
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
result

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — test explicit disambiguating contexts.
# 2. **Gather the data** — reuse audited identities and LGA.
# 3. **Explore the data** — measure support and unseen exposure before fitting.
# 4. **Clean and preprocess the data** — reuse conservative normalisation.
# 5. **Select and engineer features** — add three supported context pairs only.
# 6. **Define the machine-learning task** — unchanged three-class classification.
# 7. **Partition the data** — retain frozen folds and nested stopping.
# 8. **Select and train candidate methods** — one depth-8 CatBoost and fixed 20% vote.
# 9. **Evaluate and interpret the results** — compare directly with the identity leader.
# 10. **Deploy and iterate** — reject the context representation without opening local test.

# %% [markdown]
# ## Results

# %%
summary

# %% [markdown]
# ## Interpretation
#
# The context CatBoost standalone falls from 80.6229% to 80.4819%. At the frozen 20% contribution its changes cancel exactly in the mean, with only two fold wins and worse repair recall. CatBoost already receives the constituent categories with pairwise categorical interactions, so explicit pair construction is stopped rather than subset-tuned.
