# %% [markdown]
# # 29 — Deferred-name character text
#
# **Decision:** stop the text branch. The fixed text logistic reaches 75.619%, and its 5% contribution reduces the promoted vote to 81.705%.

# %%
from pathlib import Path
import json
import pandas as pd
PROJECT_DIR = Path('../..').resolve()
OUTPUT_DIR = PROJECT_DIR / '.runtime' / 'name-text-screen'
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col='candidate')
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
result

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — test transferable spelling fragments.
# 2. **Gather the data** — reuse all six deferred name fields.
# 3. **Explore the data** — use audited exact-name unseen exposure.
# 4. **Clean and preprocess the data** — preserve tagged normalised fields and missing states.
# 5. **Select and engineer features** — one 60,000-feature character TF-IDF policy.
# 6. **Define the machine-learning task** — unchanged three-class probabilities.
# 7. **Partition the data** — fit vocabulary and IDF inside each outer fold.
# 8. **Select and train candidate methods** — one logistic model and one 5% vote.
# 9. **Evaluate and interpret the results** — compare directly with the promoted vote.
# 10. **Deploy and iterate** — reject without local-test use.

# %% [markdown]
# ## Results

# %%
summary

# %% [markdown]
# ## Interpretation
#
# Character fragments create a distinct but weak model. Even a 5% contribution loses accuracy on four folds and worsens repair recall. The branch therefore stops without n-gram, regularisation or weight tuning.
