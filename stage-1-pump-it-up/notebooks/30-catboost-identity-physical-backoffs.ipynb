# %% [markdown]
# # 30 — CatBoost identity physical back-offs
#
# **Decision:** retain the promoted identity vote. Four deterministic physical parents add only 0.006 points at the fixed 20% contribution.

# %%
from pathlib import Path
import json
import pandas as pd
PROJECT_DIR = Path('../..').resolve()
OUTPUT_DIR = PROJECT_DIR / '.runtime' / 'catboost-identity-backoff-screen'
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col='candidate')
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
result

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — test physical parents as specialist back-offs.
# 2. **Gather the data** — reuse four deterministic raw parent categories.
# 3. **Explore the data** — reuse completed hierarchy evidence.
# 4. **Clean and preprocess the data** — apply identity categorical normalisation.
# 5. **Select and engineer features** — add all four parents only to CatBoost.
# 6. **Define the machine-learning task** — unchanged three-class classification.
# 7. **Partition the data** — preserve frozen folds and nested stopping.
# 8. **Select and train candidate methods** — one depth-8 model and fixed 20% vote.
# 9. **Evaluate and interpret the results** — compare directly with the promoted vote.
# 10. **Deploy and iterate** — reject without parent-subset tuning.

# %% [markdown]
# ## Results

# %%
summary

# %% [markdown]
# ## Interpretation
#
# The all-parent specialist is weaker standalone and changes only three aggregate development decisions in the vote. Two fold wins and a 0.006-point mean gain do not justify mining four parent subsets.
