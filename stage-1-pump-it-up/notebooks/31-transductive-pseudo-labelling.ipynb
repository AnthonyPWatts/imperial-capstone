# %% [markdown]
# # 31 — Transductive pseudo-labelling
#
# **Decision:** stop self-training. The fixed 98%-confidence student lowers the promoted vote to 81.7298%, despite three fold wins.

# %%
from pathlib import Path
import json
import pandas as pd
PROJECT_DIR = Path('../..').resolve()
OUTPUT_DIR = PROJECT_DIR / '.runtime' / 'transductive-pseudo-labelling-screen'
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col='candidate')
audit = pd.read_csv(OUTPUT_DIR / 'pseudo-label-audit.csv', index_col='validation_fold')
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
result

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — test high-confidence transductive self-training.
# 2. **Gather the data** — reuse outer training and unlabelled competition rows.
# 3. **Explore the data** — fix 98% from an outcome-free confidence audit.
# 4. **Clean and preprocess the data** — reuse accepted fold-fitted preprocessing.
# 5. **Select and engineer features** — append only selected pseudo-labelled rows.
# 6. **Define the machine-learning task** — semi-supervised three-class classification.
# 7. **Partition the data** — exclude outer validation from teacher and student fitting.
# 8. **Select and train candidate methods** — one teacher and student per fold.
# 9. **Evaluate and interpret the results** — compare components and fixed vote.
# 10. **Deploy and iterate** — reject without threshold tuning.

# %% [markdown]
# ## Pseudo-label audit

# %%
audit

# %% [markdown]
# ## Results

# %%
summary

# %% [markdown]
# ## Interpretation
#
# The high-confidence set contains no repair predictions and mostly reinforces existing majority-class decisions. Student XGBoost weakens, and its ensemble has a lower mean despite three small fold wins. The branch stops without threshold tuning.
