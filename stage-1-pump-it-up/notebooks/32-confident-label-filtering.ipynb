# %% [markdown]
# # 32 — Nested confident-label filtering
#
# **Decision:** stop outlier removal. Strictly nested confident disagreement lowers the promoted vote to 81.6835%.

# %%
from pathlib import Path
import json
import pandas as pd
PROJECT_DIR = Path('../..').resolve()
OUTPUT_DIR = PROJECT_DIR / '.runtime' / 'confident-label-filtering-screen'
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col='candidate')
audit = pd.read_csv(OUTPUT_DIR / 'removal-audit.csv', index_col='validation_fold')
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
result

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — identify only extreme likely label errors.
# 2. **Gather the data** — reuse outer-training rows and labels.
# 3. **Explore the data** — extend earlier filters with model disagreement.
# 4. **Clean and preprocess the data** — fit preprocessing inside every teacher fold.
# 5. **Select and engineer features** — remove rows crossing fixed 90%/5% conditions.
# 6. **Define the machine-learning task** — unchanged three-class classification.
# 7. **Partition the data** — use three inner OOF folds within each outer training fold.
# 8. **Select and train candidate methods** — accepted XGBoost teachers and filtered student.
# 9. **Evaluate and interpret the results** — compare component and fixed vote.
# 10. **Deploy and iterate** — reject without threshold tuning.

# %% [markdown]
# ## Removal audit

# %%
audit

# %% [markdown]
# ## Results

# %%
summary

# %% [markdown]
# ## Interpretation
#
# Even extreme nested disagreement selects valid hard cases, especially repair rows. Filtered XGBoost and its promoted-recipe substitution both weaken, so outlier removal stops without threshold tuning.
