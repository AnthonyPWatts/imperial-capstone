# %% [markdown]
# # 33 — Recording-time features
#
# **Decision:** retain elapsed days alone. Adding year, month and year-month lowers the promoted vote to 81.7109%.

# %%
from pathlib import Path
import json
import pandas as pd
PROJECT_DIR = Path('../..').resolve()
OUTPUT_DIR = PROJECT_DIR / '.runtime' / 'temporal-feature-screen'
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col='candidate')
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
result

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — test audited recording year and month.
# 2. **Gather the data** — reuse complete recording dates.
# 3. **Explore the data** — use the prior survey-span audit.
# 4. **Clean and preprocess the data** — parse strictly and retain elapsed days.
# 5. **Select and engineer features** — add year, month and year-month categories.
# 6. **Define the machine-learning task** — unchanged three-class classification.
# 7. **Partition the data** — keep all fitting inside frozen folds.
# 8. **Select and train candidate methods** — accepted XGBoost and Random Forest.
# 9. **Evaluate and interpret the results** — compare components and both votes.
# 10. **Deploy and iterate** — reject without calendar-bin tuning.

# %% [markdown]
# ## Results

# %%
summary

# %% [markdown]
# ## Interpretation
#
# Both XGBoost and Random Forest weaken with explicit calendar categories. The continuous elapsed-day feature already supports useful tree splits; extra campaign bins add variance and are stopped.
