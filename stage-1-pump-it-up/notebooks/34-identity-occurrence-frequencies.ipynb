# %% [markdown]
# # 34 — Deferred-identity occurrence frequencies
#
# **Decision:** retain native CatBoost identities alone. Six fold-fitted log occurrence counts lower the promoted vote to 81.5846%.

# %%
from pathlib import Path
import json
import pandas as pd
PROJECT_DIR = Path('../..').resolve()
OUTPUT_DIR = PROJECT_DIR / '.runtime' / 'identity-frequency-screen'
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col='candidate')
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
result

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — test whether identity support and rarity add information.
# 2. **Gather the data** — reuse all six deferred identities.
# 3. **Explore the data** — build on their audited high cardinality.
# 4. **Clean and preprocess the data** — normalise identities and map unseen values to zero.
# 5. **Select and engineer features** — add six numeric log occurrence counts.
# 6. **Define the machine-learning task** — unchanged three-class classification.
# 7. **Partition the data** — fit count mappings inside frozen outer folds.
# 8. **Select and train candidate methods** — accepted XGBoost and Random Forest.
# 9. **Evaluate and interpret the results** — compare components and both votes.
# 10. **Deploy and iterate** — reject without subset or weight tuning.

# %% [markdown]
# ## Results

# %%
summary

# %% [markdown]
# ## Interpretation
#
# Frequency improves Random Forest relative to its accepted form but damages XGBoost substantially. The promoted vote loses 0.1557 percentage points and four folds do not improve, so the fixed policy is stopped.
