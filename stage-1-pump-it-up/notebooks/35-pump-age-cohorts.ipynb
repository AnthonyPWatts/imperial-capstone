# %% [markdown]
# # 35 — Pump-age cohorts
#
# **Decision:** retain the promoted identity vote. The fixed cohort reaches 81.8035%, but its 0.0631-point gain misses the promotion gate.

# %%
from pathlib import Path
import json
import pandas as pd
PROJECT_DIR = Path('../..').resolve()
OUTPUT_DIR = PROJECT_DIR / '.runtime' / 'age-cohort-screen'
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col='candidate')
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
result

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — test broad maintenance-lifecycle cohorts.
# 2. **Gather the data** — reuse recording date and construction year.
# 3. **Explore the data** — verify support for the fixed bands.
# 4. **Clean and preprocess the data** — preserve accepted age validity states.
# 5. **Select and engineer features** — add one fixed categorical age cohort.
# 6. **Define the machine-learning task** — unchanged three-class classification.
# 7. **Partition the data** — keep all fitting inside frozen folds.
# 8. **Select and train candidate methods** — refit the three promoted component specifications.
# 9. **Evaluate and interpret the results** — compare three cohort placements.
# 10. **Deploy and iterate** — retain the incumbent without cut-point tuning.

# %% [markdown]
# ## Results

# %%
summary

# %% [markdown]
# ## Interpretation
#
# All refitted components weaken alone, while the all-component vote gains 0.0631 points through error complementarity. The gain is stable enough to record but too small to promote after repeated use of the same folds.
