# %% [markdown]
# # 36 — Complete-identity CatBoost seed bag
#
# **Decision:** retain the first seed alone. Equal averaging with one additional fixed seed lowers the promoted vote to 81.7193%.

# %%
from pathlib import Path
import json
import pandas as pd
PROJECT_DIR = Path('../..').resolve()
OUTPUT_DIR = PROJECT_DIR / '.runtime' / 'catboost-identity-seed-bag'
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col='candidate')
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
result

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — test variance reduction in the identity voter.
# 2. **Gather the data** — reuse unchanged development data and identities.
# 3. **Explore the data** — reuse the promoted first-seed OOF probabilities.
# 4. **Clean and preprocess the data** — keep feature engineering unchanged.
# 5. **Select and engineer features** — no feature change.
# 6. **Define the machine-learning task** — unchanged three-class classification.
# 7. **Partition the data** — reuse the same five frozen folds.
# 8. **Select and train candidate methods** — fit only seed 20260822.
# 9. **Evaluate and interpret the results** — compare the second seed and equal bag.
# 10. **Deploy and iterate** — retain seed 20260821 alone.

# %% [markdown]
# ## Results

# %%
summary

# %% [markdown]
# ## Interpretation
#
# The seeds disagree on 4.057% of hard predictions, but the second seed is weaker. Equal probability averaging improves standalone CatBoost while slightly reducing the final ensemble, so further seeds are not justified.
