# %% [markdown]
# # 37 — Complete physical-hierarchy identity CatBoost
#
# **Decision:** retain the complete-identity CatBoost without hierarchy back-offs. The full seven-field policy lowers the promoted vote to 81.7256%.

# %%
from pathlib import Path
import json
import pandas as pd
PROJECT_DIR = Path('../..').resolve()
OUTPUT_DIR = PROJECT_DIR / '.runtime' / 'catboost-identity-full-hierarchy'
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col='candidate')
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
result

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — test full physical hierarchy context.
# 2. **Gather the data** — reuse all seven supplied back-off fields.
# 3. **Explore the data** — build on hierarchy audits and the four-parent result.
# 4. **Clean and preprocess the data** — normalise with explicit missing states.
# 5. **Select and engineer features** — add all seven native categoricals.
# 6. **Define the machine-learning task** — unchanged three-class classification.
# 7. **Partition the data** — reuse the same five frozen folds.
# 8. **Select and train candidate methods** — refit the depth-8 identity CatBoost.
# 9. **Evaluate and interpret the results** — compare standalone and 20% vote.
# 10. **Deploy and iterate** — reject and close hierarchy subsets.

# %% [markdown]
# ## Results

# %%
summary

# %% [markdown]
# ## Interpretation
#
# All seven deterministic hierarchy back-offs repeat information from granular children. Standalone CatBoost and the final vote both weaken, so subset screening is not justified.
