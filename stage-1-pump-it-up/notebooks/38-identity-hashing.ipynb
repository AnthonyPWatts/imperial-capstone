# %% [markdown]
# # 38 — Target-free deferred-identity hashing
#
# **Decision:** retain accepted XGBoost without hashes. The fixed 4,096-column identity block lowers the promoted vote to 81.5783%.

# %%
from pathlib import Path
import json
import pandas as pd
PROJECT_DIR = Path('../..').resolve()
OUTPUT_DIR = PROJECT_DIR / '.runtime' / 'identity-hash-screen'
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col='candidate')
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
result

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — test target-free sparse-name hashing.
# 2. **Gather the data** — reuse all six deferred identities.
# 3. **Explore the data** — build on native, frequency and character-text results.
# 4. **Clean and preprocess the data** — normalise and field-prefix six tokens.
# 5. **Select and engineer features** — use one non-negative 4,096-column hash block.
# 6. **Define the machine-learning task** — unchanged three-class classification.
# 7. **Partition the data** — reuse frozen folds; hashing learns no statistics.
# 8. **Select and train candidate methods** — refit accepted XGBoost only.
# 9. **Evaluate and interpret the results** — substitute it in the promoted vote.
# 10. **Deploy and iterate** — reject without dimension or subset tuning.

# %% [markdown]
# ## Results

# %%
summary

# %% [markdown]
# ## Interpretation
#
# Hashing handles unseen identities cheaply, but bucket collisions and absent ordered-category statistics weaken XGBoost. Native CatBoost identities remain the useful sparse-name representation.
