# %% [markdown]
# # 39 — One-vs-rest XGBoost
#
# **Decision:** retain multiclass XGBoost. Independent boundaries improve standalone accuracy, but the best fixed boundary bag gains only 0.0189 points.

# %%
from pathlib import Path
import json
import pandas as pd
PROJECT_DIR = Path('../..').resolve()
OUTPUT_DIR = PROJECT_DIR / '.runtime' / 'one-vs-rest-screen'
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col='candidate')
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
result

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — test independent binary class boundaries.
# 2. **Gather the data** — reuse accepted features and unchanged labels.
# 3. **Explore the data** — build on flat, ordinal and binary-reduction evidence.
# 4. **Clean and preprocess the data** — fit accepted preprocessing inside every boundary.
# 5. **Select and engineer features** — no feature change.
# 6. **Define the machine-learning task** — three OvR tasks normalised to memberships.
# 7. **Partition the data** — keep stopping and refitting inside outer folds.
# 8. **Select and train candidate methods** — fixed unweighted child-1 XGBoost.
# 9. **Evaluate and interpret the results** — direct substitution and one equal bag.
# 10. **Deploy and iterate** — retain multiclass XGBoost.

# %% [markdown]
# ## Results

# %%
summary

# %% [markdown]
# ## Interpretation
#
# OvR improves standalone XGBoost, but its probability geometry combines less effectively with the promoted Forest and CatBoost. The equal boundary bag is stable but gains only nine development rows.
