# %% [markdown]
# # 40 — One-vs-rest complete-identity CatBoost
#
# **Decision:** retain multiclass CatBoost. The equal boundary-bag vote reaches 81.7761%, but gains only 0.0358 points at substantial cost.

# %%
from pathlib import Path
import json
import pandas as pd
PROJECT_DIR = Path('../..').resolve()
OUTPUT_DIR = PROJECT_DIR / '.runtime' / 'one-vs-rest-catboost-screen'
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col='candidate')
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
result

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — test independent native-identity boundaries.
# 2. **Gather the data** — reuse accepted features, identities and labels.
# 3. **Explore the data** — build on the XGBoost OvR standalone result.
# 4. **Clean and preprocess the data** — engineer identities inside partitions.
# 5. **Select and engineer features** — no feature change.
# 6. **Define the machine-learning task** — three OvR tasks normalised to memberships.
# 7. **Partition the data** — keep stopping and refitting inside outer folds.
# 8. **Select and train candidate methods** — fixed unweighted depth-8 CatBoost.
# 9. **Evaluate and interpret the results** — direct, equal bag and combined bag.
# 10. **Deploy and iterate** — retain multiclass CatBoost.

# %% [markdown]
# ## Results

# %%
summary

# %% [markdown]
# ## Interpretation
#
# OvR materially strengthens standalone CatBoost, but the final gain is only 17 development rows and costs about 28.9 fold-minutes. The result misses the promotion gate and closes task decomposition.
