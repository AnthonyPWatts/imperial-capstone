# %% [markdown]
# # 41 — Hard-majority decisions
#
# **Decision:** retain the promoted soft vote. Component hard majority lowers accuracy to 81.5341%.

# %%
from pathlib import Path
import json
import pandas as pd
PROJECT_DIR = Path('../..').resolve()
OUTPUT_DIR = PROJECT_DIR / '.runtime' / 'decision-combiner-screen'
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col='candidate')
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
result

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — compare hard agreement with probability strength.
# 2. **Gather the data** — reuse three aligned promoted OOF components.
# 3. **Explore the data** — count majority and all-disagree rows.
# 4. **Clean and preprocess the data** — not applicable to cached evidence.
# 5. **Select and engineer features** — not applicable.
# 6. **Define the machine-learning task** — unchanged three-class accuracy.
# 7. **Partition the data** — reuse frozen folds and keep local test closed.
# 8. **Select and train candidate methods** — no training; one fixed rule.
# 9. **Evaluate and interpret the results** — compare directly with soft vote.
# 10. **Deploy and iterate** — reject hard majority.

# %% [markdown]
# ## Results

# %%
summary

# %% [markdown]
# ## Interpretation
#
# Only 160 rows have three different component labels. Hard majority discards useful confidence on the other 47,360 rows and reduces every fold, so soft probability averaging remains preferable.
