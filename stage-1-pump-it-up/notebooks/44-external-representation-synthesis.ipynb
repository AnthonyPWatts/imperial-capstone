# %% [markdown]
# # 44 — External-representation synthesis
#
# **Decision:** retain the promoted vote. Equal averaging of the two archive-derived candidates reaches 81.7929%, a 0.0526-point gain on all five folds but below the promotion gate.

# %%
from pathlib import Path
import json
import pandas as pd
PROJECT_DIR = Path('../..').resolve()
OUTPUT_DIR = PROJECT_DIR / '.runtime' / 'external-representation-synthesis'
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col='candidate')
diversity = pd.read_csv(OUTPUT_DIR / 'diversity.csv')
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
result
# Out:
# {'archive_synthesis_weights': [0.33, 0.11, 0.18, 0.09, 0.09, 0.2],
#  'archive_synthesis_accuracy': 0.817929292929293,
#  'change_vs_promoted_identity_vote': 0.000526094276094291,
#  'passes_gate': False,
#  'age_follow_up_passes_gate': False,
#  'local_test_opened': False,
#  'competition_predictions_generated': False}

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — test complementarity of two fixed external leads once.
# 2. **Gather the data** — reuse aligned cached OOF memberships.
# 3. **Explore the data** — build on two separately positive representation bags.
# 4. **Clean and preprocess the data** — not applicable to cached fold-safe evidence.
# 5. **Select and engineer features** — no new feature; average two complete candidate votes.
# 6. **Define the machine-learning task** — unchanged three-class accuracy.
# 7. **Partition the data** — reuse identical frozen folds and keep local test closed.
# 8. **Select and train candidate methods** — no refit and no weight search.
# 9. **Evaluate and interpret the results** — compare folds, recall and changed decisions.
# 10. **Deploy and iterate** — reject promotion and stop near-miss accumulation.

# %% [markdown]
# ## Results

# %%
summary
# Out:
#                                   mean_accuracy  leader_change  \
# candidate
# archive_representation_synthesis       0.817929       0.000526
# archive_plus_age_synthesis             0.817698       0.000295
# promoted_identity_vote                 0.817403       0.000000
#
#                                   fold_wins_vs_leader  worst_fold_change  \
# candidate
# archive_representation_synthesis                    5           0.000105
# archive_plus_age_synthesis                          2          -0.000105
# promoted_identity_vote                              0           0.000000
#
#                                   repair_recall_change  passes_gate
# candidate
# archive_representation_synthesis             -0.002026        False
# archive_plus_age_synthesis                   -0.003765        False
# promoted_identity_vote                        0.000000        False

# %%
diversity
# Out:
#                                        left_model  \
# 0                 Promoted complete-identity vote
# 1                 Promoted complete-identity vote
# 2  Equal archive-derived representation synthesis
#
#                                       right_model  disagreement  \
# 0  Equal archive-derived representation synthesis      0.006902
# 1     Equal archive-synthesis and age-cohort vote      0.007660
# 2     Equal archive-synthesis and age-cohort vote      0.006902
#
#    left_only_correct  right_only_correct  both_wrong
# 0           0.002883            0.003409    0.179188
# 1           0.003388            0.003683    0.178914
# 2           0.003241            0.003009    0.179061

# %% [markdown]
# ## Interpretation
#
# The archive-derived synthesis improves every fold and makes 25 more net-correct development predictions, but the 0.053-point gain is below the promotion gate. Adding the strongest earlier feature near-miss weakens it, so broad candidate accumulation stops here.
