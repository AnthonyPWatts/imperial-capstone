# %% [markdown]
# # 45 — Transductive categorical-frequency forest
#
# **Decision:** retain the inductive synthesis. Supplied inference covariates improve the frequency forest by 0.217 points alone, but its best fixed ensemble reaches only 81.7824%.

# %%
from pathlib import Path
import json
import pandas as pd
PROJECT_DIR = Path('../..').resolve()
OUTPUT_DIR = PROJECT_DIR / '.runtime' / 'transductive-frequency-forest-screen'
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col='candidate')
rare_crossing = pd.read_csv(OUTPUT_DIR / 'rare-threshold-crossing.csv')
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
result
# Out:
# {'reference_rows': 62370,
#  'engineered_features': 43,
#  'transformed_features_fold_1': 48,
#  'transductive_synthesis_accuracy': 0.817739898989899,
#  'change_vs_promoted_identity_vote': 0.00033670033670030186,
#  'change_vs_inductive_synthesis': -0.00018939393939398919,
#  'passes_gate': False,
#  'rare_threshold_crossing_share_min': 0.2793560606060606,
#  'rare_threshold_crossing_share_max': 0.2958754208754209,
#  'local_test_opened': False,
#  'competition_predictions_generated': False}

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — reproduce target-free fixed-universe support counts.
# 2. **Gather the data** — use development and supplied competition covariates only.
# 3. **Explore the data** — audit rare-support boundary crossings.
# 4. **Clean and preprocess the data** — reuse fixed normalisation and support threshold.
# 5. **Select and engineer features** — replace 29 categorical/date values with fixed-universe counts.
# 6. **Define the machine-learning task** — unchanged three-class accuracy.
# 7. **Partition the data** — keep labels inside outer-training fits and local test closed.
# 8. **Select and train candidate methods** — refit one Random Forest and reuse fixed votes.
# 9. **Evaluate and interpret the results** — compare inductive and transductive candidates.
# 10. **Deploy and iterate** — reject promotion and stop transductive count mixing.

# %% [markdown]
# ## Results

# %%
summary
# Out:
#                                 mean_accuracy  leader_change  \
# candidate
# inductive_archive_synthesis          0.817929       0.000526
# transductive_frequency_vote          0.817824       0.000421
# transductive_archive_synthesis       0.817740       0.000337
# promoted_identity_vote               0.817403       0.000000
# transductive_frequency_forest        0.808270      -0.009133
# inductive_frequency_forest           0.806103      -0.011301
#
#                                 fold_wins_vs_leader  worst_fold_change  \
# candidate
# inductive_archive_synthesis                       5           0.000105
# transductive_frequency_vote                       4          -0.000421
# transductive_archive_synthesis                    4          -0.000631
# promoted_identity_vote                            0           0.000000
# transductive_frequency_forest                     0          -0.012311
# inductive_frequency_forest                        0          -0.014625
#
# ...

# %%
rare_crossing
# Out:
#    validation_fold  rows_crossing_any_rare_boundary     share  field_events
# 0                1                             2741  0.288405          3159
# 1                2                             2747  0.289036          3138
# 2                3                             2679  0.281881          3066
# 3                4                             2812  0.295875          3212
# 4                5                             2655  0.279356          3048

# %% [markdown]
# ## Interpretation
#
# Fixed-universe counts materially improve the compact forest, but its changed errors are less complementary than the inductive representation. The promoted and archive-synthesis recipes remain unchanged.
