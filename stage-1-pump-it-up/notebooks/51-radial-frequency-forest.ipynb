# %% [markdown]
# # Radial frequency-forest screen
#
# **Decision:** retain the existing archive synthesis. Origin distance improves the standalone occurrence-count forest by 0.1368 points, but the fixed archive substitution is flat and the equal subfamily bag adds only one net development row.

# %%
import json
from pathlib import Path
import pandas as pd

STAGE_DIR = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
OUTPUT_DIR = STAGE_DIR.parent / '.runtime' / 'radial-frequency-forest-screen'
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col=0)
diversity = pd.read_csv(OUTPUT_DIR / 'diversity.csv')
result
# Out:
# {'engineered_features': 44,
#  'transformed_features_fold_1': 50,
#  'radial_frequency_forest_accuracy': 0.8074705387205388,
#  'radial_archive_accuracy': 0.8179082491582491,
#  'change_vs_existing_archive': -2.1043771043838255e-05,
#  'frequency_subfamily_archive_accuracy': 0.8179503367003367,
#  'frequency_subfamily_change_vs_existing_archive': 2.1043771043727233e-05,
#  'frequency_subfamily_fold_wins': 1,
#  'passes_gate': False,
#  'local_test_opened': False,
#  'competition_predictions_generated': False,
#  'external_evidence': 'https://github.com/drivendataorg/pump-it-up/blob/master/madRid/PumpItUp_DataDriven_2nd_place_madRid_team.R'}

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — complete the archived frequency representation with one documented radial coordinate.
# 2. **Gather the data** — reuse supplied coordinates, frozen folds and cached promoted components.
# 3. **Explore the data** — use one fixed origin and distance formula, without a grid.
# 4. **Clean and preprocess the data** — reject invalid coordinate pairs and fit missing-value handling inside each fold.
# 5. **Select and engineer features** — add geodesic distance from `(0, 0)` to occurrence counts.
# 6. **Define the machine-learning task** — retain three-class accuracy.
# 7. **Partition the data** — preserve the five frozen development folds.
# 8. **Select and train candidate methods** — refit one Random Forest and make fixed archive substitutions.
# 9. **Evaluate and interpret the results** — compare accuracy, fold changes, repair recall and diversity.
# 10. **Deploy and iterate** — close the branch without local-test or competition inference.

# %%
display_columns = [
    'mean_accuracy', 'incumbent_change', 'fold_wins_vs_incumbent',
    'worst_fold_change', 'repair_recall_change', 'passes_gate',
]
summary.loc[:, display_columns]
# Out:
#                              mean_accuracy  incumbent_change  \
# candidate
# frequency_subfamily_archive       0.817950          0.000021
# existing_archive_synthesis        0.817929          0.000000
# radial_archive_substitution       0.817908         -0.000021
# radial_forest_bag                 0.817803         -0.000126
# promoted_identity_vote            0.817403         -0.000526
# radial_frequency_forest           0.807471         -0.010459
# existing_frequency_forest         0.806103         -0.011827
#
#                              fold_wins_vs_incumbent  worst_fold_change  \
# candidate
# frequency_subfamily_archive                       1          -0.000210
# existing_archive_synthesis                        0           0.000000
# radial_archive_substitution                       1          -0.000210
# radial_forest_bag                                 1          -0.000737
# promoted_identity_vote                            0          -0.000842
# ...

# %%
diversity.loc[
    diversity['left_model'].str.contains('all categorical occurrence counts')
    & diversity['right_model'].str.contains('origin distance'),
    ['disagreement', 'left_only_correct', 'right_only_correct', 'both_wrong'],
]
# Out:
#    disagreement  left_only_correct  right_only_correct  both_wrong
# 0      0.025337           0.010627            0.011995    0.181902

# %% [markdown]
# ## Interpretation
#
# The radial feature is useful inside the compact forest, confirming that an axis-aligned model benefits from the diagonal spatial projection. Its corrections overlap the stronger archive components, however. Direct substitution is fractionally worse, while equal averaging of the two frequency forests improves just one row and one fold. This is component evidence, not a third submission candidate.
