# %% [markdown]
# # Physical-state interaction screen
#
# **Decision:** retain the existing archive synthesis. A fixed quantity-by-physical CatBoost layer reaches 81.7908% after archive substitution, one net development row below the 81.7929% incumbent.

# %%
import json
from pathlib import Path
import pandas as pd

STAGE_DIR = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
OUTPUT_DIR = STAGE_DIR.parent / '.runtime' / 'physical-state-interaction-screen'
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col=0)
support = pd.read_csv(OUTPUT_DIR / 'interaction-support-audit.csv')
result
# Out:
# {'engineered_features': 38,
#  'categorical_features': 24,
#  'archive_substitution_accuracy': 0.8179082491582491,
#  'archive_bag_accuracy': 0.8178451178451178,
#  'best_change_vs_archive': -2.1043771043838255e-05,
#  'passes_gate': False,
#  'local_test_opened': False,
#  'competition_predictions_generated': False}

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — test whether quantity changes the meaning of physical pump and source fields.
# 2. **Gather the data** — reuse supplied physical values and cached archive components.
# 3. **Explore the data** — audit support without label-selected interaction subsets.
# 4. **Clean and preprocess the data** — reuse conservative native-category normalisation.
# 5. **Select and engineer features** — add three fixed quantity-by-physical composites.
# 6. **Define the machine-learning task** — retain three-class accuracy.
# 7. **Partition the data** — keep inner stopping and refitting within five outer folds.
# 8. **Select and train candidate methods** — fit one depth-8 identity CatBoost and make fixed substitution and bag comparisons.
# 9. **Evaluate and interpret the results** — compare accuracy, fold stability and repair recall.
# 10. **Deploy and iterate** — close the branch without local-test or competition inference.

# %%
support
# Out:
#             source  levels  singleton_row_share  rows_in_groups_at_least_20
# 0  extraction_type      77             0.000084                    0.995960
# 1           source      50             0.000000                    0.998380
# 2  waterpoint_type      32             0.000042                    0.999158

# %%
summary.loc[:, [
    'mean_accuracy', 'incumbent_change', 'fold_wins_vs_incumbent',
    'worst_fold_change', 'repair_recall_change', 'passes_gate',
]]
# Out:
#                                   mean_accuracy  incumbent_change  \
# candidate
# existing_archive_synthesis             0.817929          0.000000
# interaction_archive_substitution       0.817908         -0.000021
# interaction_archive_bag                0.817845         -0.000084
# promoted_identity_vote                 0.817403         -0.000526
# interaction_direct_bag                 0.817361         -0.000568
# interaction_direct_vote                0.817319         -0.000610
# interaction_catboost                   0.805072         -0.012858
#
#                                   fold_wins_vs_incumbent  worst_fold_change  \
# candidate
# existing_archive_synthesis                             0           0.000000
# interaction_archive_substitution                       3          -0.001368
# interaction_archive_bag                                1          -0.000631
# promoted_identity_vote                                 0          -0.000842
# ...

# %% [markdown]
# ## Interpretation
#
# The composite levels are well supported, but their gains vary by fold. The archive replacement wins three folds while losing slightly more in the other two, and the equal CatBoost bag is also below the incumbent. The interaction layer is therefore not a third submission candidate.
