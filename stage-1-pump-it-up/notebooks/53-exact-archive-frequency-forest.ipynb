# %% [markdown]
# # Exact archive frequency-forest screen
#
# **Decision:** retain the existing archive synthesis. The adapted 1,000-tree, five-feature-per-split forest reaches 80.7281% standalone and 81.7761% after archive substitution, below the corresponding incumbents.

# %%
import json
from pathlib import Path
import pandas as pd

STAGE_DIR = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
OUTPUT_DIR = STAGE_DIR.parent / '.runtime' / 'exact-archive-frequency-forest-screen'
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col=0)
diversity = pd.read_csv(OUTPUT_DIR / 'diversity.csv')
result
# Out:
# {'trees': 1000,
#  'max_features': 5,
#  'engineered_features': 44,
#  'transformed_features_fold_1': 50,
#  'standalone_accuracy': 0.8072811447811448,
#  'archive_substitution_accuracy': 0.8177609427609427,
#  'change_vs_existing_archive': -0.00016835016835026195,
#  'passes_gate': False,
#  'local_test_opened': False,
#  'competition_predictions_generated': False}

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — reproduce the missing documented forest settings from the archived solution.
# 2. **Gather the data** — reuse supplied data, frozen folds and cached archive components.
# 3. **Explore the data** — compare one exact adapted specification with existing frequency forests.
# 4. **Clean and preprocess the data** — retain fold-fitted counts and valid radial distance.
# 5. **Select and engineer features** — keep the 44-feature radial count representation fixed.
# 6. **Define the machine-learning task** — retain three-class accuracy.
# 7. **Partition the data** — fit all learned state inside five outer-training folds.
# 8. **Select and train candidate methods** — fit 1,000 trees with five candidate features per split.
# 9. **Evaluate and interpret the results** — compare standalone, diversity and archive substitution evidence.
# 10. **Deploy and iterate** — close without local-test or competition inference.

# %%
summary.loc[:, [
    'mean_accuracy', 'incumbent_change', 'fold_wins_vs_incumbent',
    'worst_fold_change', 'repair_recall_change', 'passes_gate',
]]
# Out:
#                                 mean_accuracy  incumbent_change  \
# candidate
# existing_archive_synthesis           0.817929          0.000000
# exact_archive_substitution           0.817761         -0.000168
# radial_frequency_forest              0.807471         -0.010459
# exact_archive_frequency_forest       0.807281         -0.010648
# existing_frequency_forest            0.806103         -0.011827
#
#                                 fold_wins_vs_incumbent  worst_fold_change  \
# candidate
# existing_archive_synthesis                           0           0.000000
# exact_archive_substitution                           1          -0.000421
# radial_frequency_forest                              0          -0.012416
# exact_archive_frequency_forest                       0          -0.012311
# existing_frequency_forest                            0          -0.015152
#
#                                 repair_recall_change  passes_gate
# candidate
# ...

# %%
diversity.loc[
    diversity['left_model'].str.contains('origin distance')
    & diversity['right_model'].str.contains('exact adapted'),
    ['disagreement', 'left_only_correct', 'right_only_correct', 'both_wrong'],
]
# Out:
#    disagreement  left_only_correct  right_only_correct  both_wrong
# 4      0.019676           0.008965            0.008775    0.183754

# %% [markdown]
# ## Interpretation
#
# The faithful tree count and feature-sampling value do not improve the radial component. The earlier radial feature was the useful archived clue; substituting the exact-spec forest loses eight net development rows in the final archive ensemble.
