# %% [markdown]
# # Radial Random Forest screen
#
# **Decision:** retain the existing archive synthesis. Radial distance improves the accepted forest by only two net rows; its equal archive bag reaches 81.8056%, a 0.0126-point gain with 2/5 fold wins.

# %%
import json
from pathlib import Path
import pandas as pd

STAGE_DIR = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
OUTPUT_DIR = STAGE_DIR.parent / '.runtime' / 'radial-random-forest-screen'
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col=0)
diversity = pd.read_csv(OUTPUT_DIR / 'diversity.csv')
result
# Out:
# {'engineered_features': 30,
#  'transformed_features_fold_1': 303,
#  'radial_random_forest_accuracy': 0.8059553872053872,
#  'best_archive_accuracy': 0.8180555555555555,
#  'best_change_vs_archive': 0.00012626262626258544,
#  'passes_gate': False,
#  'local_test_opened': False,
#  'competition_predictions_generated': False}

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — test whether radial distance strengthens the accepted Random Forest.
# 2. **Gather the data** — reuse supplied coordinates, frozen folds and cached archive components.
# 3. **Explore the data** — retain one already-fixed origin-distance definition.
# 4. **Clean and preprocess the data** — validate coordinates and fit missing-value handling inside each fold.
# 5. **Select and engineer features** — append one target-free radial distance.
# 6. **Define the machine-learning task** — retain three-class accuracy.
# 7. **Partition the data** — keep all learned preprocessing and fitting inside five outer folds.
# 8. **Select and train candidate methods** — refit one accepted-spec forest and make fixed substitution and bag comparisons.
# 9. **Evaluate and interpret the results** — compare accuracy, fold stability, repair recall and diversity.
# 10. **Deploy and iterate** — close without local-test or competition inference.

# %%
summary.loc[:, [
    'mean_accuracy', 'incumbent_change', 'fold_wins_vs_incumbent',
    'worst_fold_change', 'repair_recall_change', 'passes_gate',
]]
# Out:
#                               mean_accuracy  incumbent_change  \
# candidate
# archive_radial_bag                 0.818056          0.000126
# archive_radial_substitution        0.817950          0.000021
# existing_archive_synthesis         0.817929          0.000000
# promoted_radial_bag                0.817508         -0.000421
# promoted_identity_vote             0.817403         -0.000526
# promoted_radial_substitution       0.817319         -0.000610
# radial_random_forest               0.805955         -0.011974
# accepted_random_forest             0.805913         -0.012016
#
#                               fold_wins_vs_incumbent  worst_fold_change  \
# candidate
# archive_radial_bag                                 2          -0.000526
# archive_radial_substitution                        4          -0.000947
# existing_archive_synthesis                         0           0.000000
# promoted_radial_bag                                2          -0.001473
# ...

# %%
diversity.loc[
    diversity['left_model'].str.contains('baseline')
    & diversity['right_model'].str.contains('origin distance'),
    ['disagreement', 'left_only_correct', 'right_only_correct', 'both_wrong'],
]
# Out:
#    disagreement  left_only_correct  right_only_correct  both_wrong
# 0      0.026515           0.011827            0.011869    0.182218

# %% [markdown]
# ## Interpretation
#
# The radial projection produces balanced but tiny forest corrections. Equal averaging adds six net rows to the archive vote, with insufficient mean gain and fold stability for promotion. It is not a third submission candidate.
