# %% [markdown]
# # Probability-stack screen
#
# **Decision:** retain the fixed arithmetic archive synthesis. A centred-log multinomial combiner reaches 81.5867%, losing 0.2062 points and all five folds.

# %%
import json
from pathlib import Path
import pandas as pd

STAGE_DIR = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
OUTPUT_DIR = STAGE_DIR.parent / '.runtime' / 'probability-stack-screen'
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col=0)
diagnostics = pd.read_csv(OUTPUT_DIR / 'fold-diagnostics.csv', index_col=0)
result
# Out:
# {'components': ['XGBoost depth 8 child 1 [baseline; frozen stratified folds]',
#   'XGBoost depth 8 child 1 [spatial height imputation]',
#   'Random Forest [baseline; frozen stratified folds]',
#   'Random Forest [all categorical occurrence counts]',
#   'Random Forest [spatial height imputation]',
#   'CatBoost d8 [complete deferred identities]'],
#  'meta_features': 18,
#  'stack_accuracy': 0.8158670033670035,
#  'change_vs_archive': -0.0020622895622894877,
#  'fold_wins': 0,
#  'passes_gate': False,
#  'strict_nested_base_refit_run': False,
#  'local_test_opened': False,
#  'competition_predictions_generated': False}

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — learn class-specific trust across the six archive components.
# 2. **Gather the data** — reuse aligned OOF component memberships.
# 3. **Explore the data** — fix one centred-log representation without a grid.
# 4. **Clean and preprocess the data** — clip numerical zero and standardise inside each meta fold.
# 5. **Select and engineer features** — create 18 centred log-membership features.
# 6. **Define the machine-learning task** — retain three-class accuracy.
# 7. **Partition the data** — fit on four OOF folds and score the fifth.
# 8. **Select and train candidate methods** — fit one L2 multinomial logistic combiner.
# 9. **Evaluate and interpret the results** — compare accuracy, folds and repair recall with arithmetic pooling.
# 10. **Deploy and iterate** — stop before strict nested refits, local test or competition inference.

# %%
summary
# Out:
#                             mean_accuracy  incumbent_change  \
# candidate
# existing_archive_synthesis       0.817929          0.000000
# probability_stack                0.815867         -0.002062
#
#                             fold_wins_vs_incumbent  worst_fold_change  \
# candidate
# existing_archive_synthesis                       0           0.000000
# probability_stack                                0          -0.002736
#
#                             repair_recall_change  passes_gate
# candidate
# existing_archive_synthesis              0.000000        False
# probability_stack                      -0.026928        False

# %%
diagnostics
# Out:
#                  total_seconds  meta_features  iterations  coefficient_l2_norm
# validation_fold
# 1                     0.137993             18          43             1.267610
# 2                     0.132733             18          43             1.184867
# 3                     0.128210             18          42             1.245756
# 4                     0.129943             18          46             1.194320
# 5                     0.126157             18          40             1.204387

# %% [markdown]
# ## Interpretation
#
# The combiner converges normally but over-corrects already calibrated memberships, particularly for repair. Because the cheap diagnostic loses every fold, expensive strict nested base refits are not justified and no local-test evidence is consumed.
