# %% [markdown]
# # Cumulative XGBoost screen
#
# **Decision:** retain the arithmetic archive synthesis. The equal multiclass/cumulative boundary bag reaches 81.8035%, only 0.0105 points above the incumbent and far below the promotion gate.

# %%
import json
from pathlib import Path
import pandas as pd

STAGE_DIR = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
OUTPUT_DIR = STAGE_DIR.parent / '.runtime' / 'ordinal-xgboost-screen'
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col=0)
diagnostics = pd.read_csv(OUTPUT_DIR / 'fold-diagnostics.csv', index_col=0)
result
# Out:
# {'class_labels': ['functional', 'functional needs repair', 'non functional'],
#  'cumulative_xgboost_accuracy': 0.8101430976430978,
#  'best_archive_accuracy': 0.8180345117845118,
#  'best_change_vs_archive': 0.00010521885521885821,
#  'passes_gate': False,
#  'local_test_opened': False,
#  'competition_predictions_generated': False}

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — test ordered target decomposition as a new ensemble signal.
# 2. **Gather the data** — reuse frozen development data and archive OOF probabilities.
# 3. **Explore the data** — inspect cumulative-boundary crossings without threshold tuning.
# 4. **Clean and preprocess the data** — reuse accepted fold-fitted one-hot preprocessing.
# 5. **Select and engineer features** — retain accepted predictors and change only the target representation.
# 6. **Define the machine-learning task** — fit two cumulative binary boundaries and reconstruct three memberships.
# 7. **Partition the data** — use the five frozen outer folds with inner early stopping.
# 8. **Select and train candidate methods** — fit accepted-spec XGBoost to each boundary.
# 9. **Evaluate and interpret the results** — compare standalone, substitution and equal boundary-bag accuracy.
# 10. **Deploy and iterate** — stop before local or competition use because the development gate fails.

# %%
summary
# Out:
#                               mean_accuracy  incumbent_change  \
# candidate
# ordinal_archive_bag                0.818035          0.000105
# existing_archive_synthesis         0.817929          0.000000
# ordinal_archive_substitution       0.817677         -0.000253
# cumulative_xgboost                 0.810143         -0.007786
# accepted_multiclass_xgboost        0.810143         -0.007786
#
#                               fold_wins_vs_incumbent  worst_fold_change  \
# candidate
# ordinal_archive_bag                                3          -0.000526
# existing_archive_synthesis                         0           0.000000
# ordinal_archive_substitution                       3          -0.001157
# cumulative_xgboost                                 0          -0.010311
# accepted_multiclass_xgboost                        0          -0.009575
#
#                               repair_recall_change  passes_gate
# candidate
# ...

# %%
diagnostics
# Out:
#                  inner_training_rows  validation_rows  \
# validation_fold
# 1                              38016             9504
# 2                              38016             9504
# 3                              38016             9504
# 4                              38016             9504
# 5                              38016             9504
#
#                  repair_or_worse_selected_iterations  \
# validation_fold
# 1                                               1225
# 2                                               1032
# 3                                               1031
# 4                                               1269
# 5                                               1199
#
#                  non_functional_selected_iterations  crossing_share  \
# validation_fold
# 1                                              1208        0.248948
# 2                                              1439        0.267992
# ...

# %% [markdown]
# ## Interpretation
#
# Cumulative XGBoost matches the accepted multiclass component but is not stronger. Roughly one quarter of rows need deterministic coherence projection. The equal boundary bag adds only five correct archive predictions, so no local-test evidence is consumed and no competition file is generated.
