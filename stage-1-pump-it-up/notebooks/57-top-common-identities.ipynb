# %% [markdown]
# # Top-common identity XGBoost screen
#
# **Decision:** retain the prepared archive synthesis. Top-50 identity indicators strengthen XGBoost, but their best archive bag gains only 0.0210 points and misses the promotion gate.

# %%
import json
from pathlib import Path
import pandas as pd

STAGE_DIR = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
OUTPUT_DIR = STAGE_DIR.parent / '.runtime' / 'top-common-identity-screen'
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col=0)
diversity = pd.read_csv(OUTPUT_DIR / 'diversity.csv', index_col=[0, 1])
result
# Out:
# {'indicator_features': 300,
#  'transformed_features_fold_1': 601,
#  'training_coverage_fold_1': 0.4081088664421998,
#  'top_50_xgboost_accuracy': 0.8108796296296298,
#  'best_archive_accuracy': 0.8181397306397307,
#  'best_change_vs_archive': 0.00021043771043771642,
#  'passes_gate': False,
#  'local_test_opened': False,
#  'competition_predictions_generated': False}

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — test a compact sparse-identity representation absent from earlier screens.
# 2. **Gather the data** — reuse six supplied identity fields and frozen development rows.
# 3. **Explore the data** — identify the archived 0.8264 solution's top-common indicators.
# 4. **Clean and preprocess the data** — preserve exact strings and fit common-value lists within each training fold.
# 5. **Select and engineer features** — add 50 indicators per identity field.
# 6. **Define the machine-learning task** — retain three-class probabilistic classification and accuracy.
# 7. **Partition the data** — reuse frozen outer folds and nested early stopping.
# 8. **Select and train candidate methods** — fit one accepted-spec XGBoost without a cut-off grid.
# 9. **Evaluate and interpret the results** — compare standalone, substitution and equal representation bag.
# 10. **Deploy and iterate** — stop before local or competition use because the gate fails.

# %%
summary
# Out:
#                              mean_accuracy  incumbent_change  \
# candidate
# top_50_archive_bag                0.818140          0.000210
# existing_archive_synthesis        0.817929          0.000000
# top_50_archive_substitution       0.817761         -0.000168
# top_50_identity_xgboost           0.810880         -0.007050
# accepted_xgboost                  0.810143         -0.007786
#
#                              fold_wins_vs_incumbent  worst_fold_change  \
# candidate
# top_50_archive_bag                                3          -0.000631
# existing_archive_synthesis                        0           0.000000
# top_50_archive_substitution                       3          -0.002104
# top_50_identity_xgboost                           0          -0.011048
# accepted_xgboost                                  0          -0.009575
#
#                              repair_recall_change  passes_gate
# candidate
# top_50_archive_bag                      -0.002607        False
# ...

# %%
diversity
# Out:
#                                                                                                        disagreement  \
# left_model                                         right_model
# XGBoost depth 8 child 1 [baseline; frozen strat... XGBoost depth 8 child 1 [top-50 deferred identi...      0.037668
#                                                    Existing archive synthesis                              0.039268
#                                                    Top-50 identity XGBoost archive substitution            0.045349
#                                                    Equal accepted/top-50 XGBoost archive bag               0.041035
# XGBoost depth 8 child 1 [top-50 deferred identi... Existing archive synthesis                              0.047391
#                                                    Top-50 identity XGBoost archive substitution            0.040088
# ...

# %% [markdown]
# ## Interpretation
#
# The fixed 300-column block produces a stronger and meaningfully different XGBoost component. Its equal archive bag adds only ten net correct rows, however, so cut-off and weight tuning would overreact to reused-fold noise.
