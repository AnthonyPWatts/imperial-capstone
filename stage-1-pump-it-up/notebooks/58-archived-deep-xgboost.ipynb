# %% [markdown]
# # Archived deep XGBoost screen
#
# **Decision:** retain the prepared archive synthesis. One depth-17 substitution reaches 81.8771%, but misses the promotion gate; the predeclared three-seed average falls to 81.8582%.

# %%
import json
from pathlib import Path
import pandas as pd

STAGE_DIR = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
OUTPUT_DIR = STAGE_DIR.parent / '.runtime' / 'archived-deep-xgboost-screen'
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col=0)
diagnostics = pd.read_csv(OUTPUT_DIR / 'fold-diagnostics.csv', index_col=0)
result
# Out:
# {'seeds': [20260822, 20260823, 20260824],
#  'iterations': 600,
#  'archived_depth_17_seed_bag_accuracy': 0.8146464646464647,
#  'best_archive_accuracy': 0.8187710437710438,
#  'best_change_vs_archive': 0.0008417508417508657,
#  'passes_gate': False,
#  'seed_bag_run': True,
#  'local_test_opened': False,
#  'competition_predictions_generated': False}

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — test the archived final learner without reopening a broad grid.
# 2. **Gather the data** — reuse supplied fields, frozen folds and archive components.
# 3. **Explore the data** — identify a depth/regularisation regime outside existing cached candidates.
# 4. **Clean and preprocess the data** — fit top-50 identity indicators within each training fold.
# 5. **Select and engineer features** — retain the fixed positive top-common representation.
# 6. **Define the machine-learning task** — retain three-class accuracy.
# 7. **Partition the data** — reuse five frozen folds without an inner tree-count search.
# 8. **Select and train candidate methods** — fit the exact depth-17, 600-tree archived specification.
# 9. **Evaluate and interpret the results** — compare substitution, representation bag and a bounded three-seed bag.
# 10. **Deploy and iterate** — stop before local or competition use because the gate fails.

# %%
summary
# Out:
#                                     mean_accuracy  incumbent_change  \
# candidate
# deep_archive_substitution                0.818771          0.000842
# deep_seed_bag_archive_substitution       0.818582          0.000652
# deep_archive_bag                         0.818266          0.000337
# existing_top_50_archive_bag              0.818140          0.000210
# existing_archive_synthesis               0.817929          0.000000
# archived_depth_17_seed_20260824          0.814731         -0.003199
# archived_depth_17_seed_20260822          0.814710         -0.003220
# archived_depth_17_seed_20260823          0.814646         -0.003283
# archived_depth_17_seed_bag               0.814646         -0.003283
# top_50_depth_8_xgboost                   0.810880         -0.007050
# accepted_xgboost                         0.810143         -0.007786
#
#                                     fold_wins_vs_incumbent  worst_fold_change  \
# candidate
# ...

# %%
diagnostics
# Out:
#                  selected_iterations  inner_fit_rows  inner_stop_rows  \
# validation_fold
# 1                                600           38016                0
# 2                                600           38016                0
# 3                                600           38016                0
# 4                                600           38016                0
# 5                                600           38016                0
#
#                  stopping_seconds  refit_predict_seconds  total_seconds
# validation_fold
# 1                             0.0              19.171022      19.211320
# 2                             0.0              19.177256      19.217786
# 3                             0.0              19.715104      19.755578
# 4                             0.0              19.567914      19.615001
# 5                             0.0              19.034229      19.077503

# %% [markdown]
# ## Interpretation
#
# Depth 17 is a substantially stronger, more diverse component. Its best single-seed archive result remains eight rows below the promotion gate, and equal seed averaging weakens it. Selecting the lucky seed or tuning around the near-miss would overfit reused development folds.
