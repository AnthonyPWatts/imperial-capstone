# %% [markdown]
# # Deep occurrence-support XGBoost screen
#
# **Decision:** retain occurrence-free archived deep XGBoost. Category support weakens both the component and its fixed archive substitution.

# %%
import json
from pathlib import Path
import pandas as pd

STAGE_DIR = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
OUTPUT_DIR = STAGE_DIR.parent / '.runtime' / 'deep-occurrence-xgboost-screen'
result = json.loads((OUTPUT_DIR / 'result.json').read_text(encoding='utf-8'))
summary = pd.read_csv(OUTPUT_DIR / 'candidate-summary.csv', index_col=0)
diversity = pd.read_csv(OUTPUT_DIR / 'diversity.csv', index_col=[0, 1])
result
# Out:
# {'occurrence_fields': 29,
#  'minimum_support': 5,
#  'occurrence_deep_accuracy': 0.813047138047138,
#  'archive_accuracy': 0.8178661616161615,
#  'archive_change': -6.313131313140374e-05,
#  'passes_gate': False,
#  'local_test_opened': False,
#  'competition_predictions_generated': False}

# %% [markdown]
# ## Course-aligned lifecycle
#
# 1. **Define the goal and scope** — test whether occurrence support complements top-common identities.
# 2. **Gather the data** — reuse supplied predictors and frozen development rows.
# 3. **Explore the data** — cross two useful archive signals without opening a grid.
# 4. **Clean and preprocess the data** — fit support inside each fold and map counts below five to the rare marker.
# 5. **Select and engineer features** — add support for all 29 categorical fields.
# 6. **Define the machine-learning task** — retain three-class accuracy.
# 7. **Partition the data** — reuse the five frozen stratified folds.
# 8. **Select and train candidate methods** — fit one predeclared archived depth-17 XGBoost seed.
# 9. **Evaluate and interpret the results** — compare the component and fixed archive substitution.
# 10. **Deploy and iterate** — stop before local or competition use because accuracy weakens.

# %%
display(summary.style.format({
    'mean_accuracy': '{:.4%}',
    'incumbent_change': '{:+.4%}',
    'worst_fold_change': '{:+.4%}',
    'repair_recall_change': '{:+.4%}',
}))
diversity.loc[[
    ('XGBoost archived depth 17 [top-50 deferred identities; seed 20260822]',
     'XGBoost archived depth 17 [top-50 identities plus occurrence support; seed 20260822]')
]]
# Out:
# <style type="text/css">
# </style>
# <table id="T_36d05">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36d05_level0_col0" class="col_heading level0 col0" >mean_accuracy</th>
#       <th id="T_36d05_level0_col1" class="col_heading level0 col1" >incumbent_change</th>
#       <th id="T_36d05_level0_col2" class="col_heading level0 col2" >fold_wins_vs_incumbent</th>
#       <th id="T_36d05_level0_col3" class="col_heading level0 col3" >worst_fold_change</th>
#       <th id="T_36d05_level0_col4" class="col_heading level0 col4" >repair_recall_change</th>
#       <th id="T_36d05_level0_col5" class="col_heading level0 col5" >passes_gate</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >candidate</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
# ...

# %% [markdown]
# ## Conclusion
#
# The occurrence-support component falls from **81.4710%** to **81.3047%**. Its archive substitution reaches **81.7866%**, 0.0063 percentage points below the archive incumbent. The branch is closed without opening the local test or generating competition predictions.
